# %%
import os

# %%
workingDirectory=os.gwd()
listDirectory=os.listdir(workingDirectory)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-26ff3cfbf2ce> in <module>
# ----> 1 workingDirectory=os.gwd()
#       2 listDirectory=os.listdir(workingDirectory)
#
# AttributeError: module 'os' has no attribute 'gwd'
