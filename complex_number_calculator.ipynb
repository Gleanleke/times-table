# %%
import complex_number_calculator_module
x=complex(input("enter the first number "))

o=input("what is the operator ")

y=complex(input("enter the second number "))



print(complex_number_calculator_module.calculator(x,y,o))
# Out:
# enter the first number 6+3j
# what is the operator -
# enter the second number 5-7j
# (1+10j)
