# %%
file=open('data.txt', 'r')
for i in file:
    print(i)
# Out:
# my first file

# %%
file=open('data.txt', 'w')
file.write(input())
# Out:
# the write command allows us to do a number of stuffs using cmd
# 62

# %%
file=open('data.txt', 'r')
for i in file:
    print(i)
# Out:
# the write command allows us to do a number of stuffs using cmd

# %%
file=open('data.txt', 'a')
file.write(input())
# Out:
# 0

# %%
file=open('data.txt', 'r')
for i in file:
    print(i)
# Out:
# the write command allows us to do a number of stuffs using cmdthis will add another line

# %%
import os, os. path

# %%
print(os.getcwd())
# Out:
# C:\Users\F3LX\Documents\LEKE GLEAN

# %%
home_dir=os.path.expanduser('~')
print(home_dir)
os.chdir(home_dir)
print(os.getcwd())
# Out:
# C:\Users\F3LX
# C:\Users\F3LX

# %%
print(os.listdir())
# Out:
# ['.bash_history', '.conda', '.condarc', '.git', '.git-for-windows-updater', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lesshst', '.matplotlib', '.spyder-py3', '.ssh', '.viminfo', '.VirtualBox', '.vscode', 'anaconda', 'anaconda3', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'Links', 'Local Settings', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{3e525a2d-a27c-11f0-8c98-0892049c2bbb}.TM.blf', 'NTUSER.DAT{3e525a2d-a27c-11f0-8c98-0892049c2bbb}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{3e525a2d-a27c-11f0-8c98-0892049c2bbb}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'quartus2.ini', 'quartus2.qreg', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Videos', 'VirtualBox VMs']
