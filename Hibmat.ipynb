# %%
HUIBAI={
}
for i in range(100):
    key=input("enter the key")
    value=input(f"what is the value of {key}")
    
    HUIBAI.update({key: value})
# Out:
# enter the keyStarted as social entrepreneurial project
# what is the value of Started as social entrepreneurial project2007
# enter the keyResearch conducted on skill gaps; MINESUP aware of need to professionalize education
# what is the value of Research conducted on skill gaps; MINESUP aware of need to professionalize education2008
# enter the keyFormally accredited by MINEFOP as CBMT
# what is the value of Formally accredited by MINEFOP as CBMT2009
# enter the keyApproved by MINESUP as HIBMAT-BUEA (orders 11/0041/MINESUP and 10/04333/L/DDES/ESUP/SER, 03 August 2010)
# what is the value of Approved by MINESUP as HIBMAT-BUEA (orders 11/0041/MINESUP and 10/04333/L/DDES/ESUP/SER, 03 August 2010)2010
# enter the keySteady enrolment growth at minimum 80% annually
# what is the value of Steady enrolment growth at minimum 80% annually 2010-2012
# enter the keyAcquired land and started second campus construction
# ...

# %%
print(HUIBAI)
# Out:
# {'Started as social entrepreneurial project': '2007', 'Research conducted on skill gaps; MINESUP aware of need to professionalize education': '2008', 'Formally accredited by MINEFOP as CBMT': '2009', 'Approved by MINESUP as HIBMAT-BUEA (orders 11/0041/MINESUP and 10/04333/L/DDES/ESUP/SER, 03 August 2010)': '2010', 'Steady enrolment growth at minimum 80% annually': ' 2010-2012', 'Acquired land and started second campus construction': '2011', 'Signed MOU with University of Bamenda for top-up degrees': '2013', 'Graduated about 11th batch from bachelor program (original estimate; now extended)': 'Up to ~2024', 'Restructured to university institute, renamed HUIB (authorization 22-02654/L/MINESUP/DDES/SD-ESUP/SDA/LAN, 20 April 2022)': 'April 2022', 'Extension of SPA with University of Bamenda for B-Tech and MBA': 'December 30, 2020', 'Framework and Specific Agreements with University of Buea for B.Sc programs': 'June 17, 2021', 'May 23, 2025: Extended strategic agreement with UB for health
# ...

# %%
HUIBAI={
    'challenges' or 'Challenges' or 'challenge' or 'Challenge' : '• Skill gaps among average English-speaking Cameroonians who cannot afford high foreign qualification fees. \n • Widening skill gaps between foreign qualification holders and state university graduates. \n • State university curriculums not aligned with industry exigencies in most specializations. \n • Underprivileged youths at crossroads in academic/professional journeys. \n • Growth challenges by 2011, prompting land acquisition and new campus construction. \n • Lack of quality experts in core Engineering and Business fields in Cameroon (updated goal to address this). \n • Adverse effects of globalization on Technology and Business activities. \n • Need to create wealth through job creation and raise living standards in Cameroon. \n • Challenges at Douala Campus (mentioned in 2025 posts, with assurances of ongoing measures like relocation plans). \n • Complexity of subjects like shorthand leading to poor student performance (from research studies). \n • Ensuring global exposure and employability in a competitive market.',
    'Programs' or 'Program' or 'programs' 'program' or 'Qualifications' or 'Qualification' or 'qualifications' or 'qualification'  :  '• Initially: Professional short courses and international benchmarks like ACCA, CIMA, CIM (evaluated by foreign bodies). \n • Authorized: Higher National Diploma (HND), Higher Professional Diploma (HPD). \n• Top-up: One-year degree for HND/HPD graduates. \n• Bachelor: In partnership with University of Bamenda (attestations issued). \n• Current: Two-year HND for GCE A-level holders; B-Tech and MBA (mentored by UBa); one-year top-up B.Sc and three-year B.Sc (mentored by UB). \n• Schools: School of Business and Management Sciences; School of Engineering and Technology; School of Health Sciences (added/emphasized by 2025).',
    'Campuses' or 'Infrastructure': '• Initial: Single campus at Check Point, Molyko, opposite stadium. \n• Second: Adjacent to Molyko sport complex, road to Bokova. \n• Current: 2 campuses in Buea, 1 in Douala (equipped with modern facilities and library). \n• Library Access: For board members, registered students, current staff, other course-takers, graduates/former staff in good standing.',
    'administration' or 'Overview' or 'overview': '• HIBMAT as Vocational Training Institute (from 2009). \n• HIBMAT as Professional University Institute (from 2010, restructured 2022 to HUIB). \n• Partnership with University of Bamenda (from 2013, extended 2020). \n• Manpower: 42 teaching staff, 7 non-teaching staff (original; current global teachers 0+ per site metrics, likely placeholder). \n• Administration Model: Modified Business University Model (President for non-academic, Rector for academic; VC duties split). \n• Perspectives: Focused on national/international visibility. \n• Organizational Structure: Illustrated in Figure 1 (BOD as highest policy organ, constituted by founding body memo). \n• Mission/Vision: Professional/affordable education for empowerment; demystify technology, train for contemporary careers, attract investment. \n• Enrolment: Grew 80%+ annually 2010-2012; current admissions ongoing for 2025/2026. \n• Mentorship: By University of Buea and University of Bamenda (Anglo-Saxon style).Overview of HIBMAT University Institute of Buea (HUIB)'
}
Role={'Owner'or'BOD Chairman  'or 'Founder'or' President'or' CEO':'Dr. Jude Chilaka (supervisory governance role over the entire institution).','Rector (Academic Head)': 'prof. Cashmin Ibrahim Talla', 'Director of Administration (Head of Admin, Oversees Supervisors)': 'Dr. Patrick Akamin', 'Director of Students Affairs': 'Mrs. Chilaka Arrah (assists with student problems, in charge of Student Representative and Socio-Cultural Supervisor)', 'Finance Officer': 'Mme. Ahone Mercy (handles day-to-day business, keeps financial records).', 'Dean of Studies': 'Coordinates student and lecturer affairs (answerable to Rector, heads Deputy Dean)', 'Deputy Dean': 'Assists Dean in absenteeism cases (reports to Dean, oversees coordinators and Library Supervisor).', 'Registrar': ' Dr. Agbor Tah (confirms and signs result slips, scrutinizes and approves admission documents)', 'Deputy Registrar': 'Mr. Ndango Donatus (assists Registrar, performs same functions, reports to Registrar, oversees Admission Office)', 'Admission Officer': 'Mr. Fanka Leonard (responsible for admissions and enquiries, reports to Deputy Registrar).', 'Director of Cooperation and Institutional Development': 'Places students on internships (answerable to Rector).', 'Deputy Director of Cooperation and Institutional Development': 'Assists Director (reports to Director).', 'Library Supervisor': 'Controls the library (reports to Deputy Dean).', 'HND Coordinator': 'Coordinates HND exams and structures courses (reports to Deputy Dean)', 'HPD Coordinator': 'Oversees HPD programs (reports to Deputy Dean).', 'B. TECH Coordinator': 'Coordinates B. TECH exams and structures courses/syllabus (reports to Deputy Dean).', 'Post Graduate Coordinator': 'Coordinates post-graduate exams and structures courses/syllabus (reports to Deputy Dean).', 'Coordinator of Short Courses': 'Coordinates short courses and structures courses/syllabus (reports to Deputy Dean).', 'Student Representative': ' Hears student problems, channels them, speaks on behalf of students.', 'Socio-Cultural Supervisor': 'Promotes social and cultural aspects, including musical groups and tribal associations (reports to Director of Students Affairs).', 'Security Supervisor': 'Ensures safety, maintains tranquility, prevents uprisings (reports to Director of Administration).', 'Catering Supervisor': 'Monitors catering, ensures quality, provides services during ceremonies (reports to Director of Administration).', ' Human Resource Officer': 'Coordinates human investment projects (reports to Director of Administration).', 'Health Supervisor': 'Handles institution health, grants permissions for sick students after assessment (reports to Director of Administration).', 'IT Lab Supervisor': 'In charge of IT laboratory, ensures equipment safety, issues access (reports to Director of Administration, based on structure).', ' Procurement Supervisor': ' Supervises institution’s expenses (reports to Director of Administration)', 'Logistics Supervisor': 'Coordinates logistics (accountable to Director of Administration).', ' Business Supervisor': 'In charge of business aspects (reports to Director of Administration).', 'BOD Chairman': 'Official head (President, Mr. Chilaka A. Jude).'}
When={'Started as social entrepreneurial project': '2007', 'Research conducted on skill gaps; MINESUP aware of need to professionalize education': '2008', 'Formally accredited by MINEFOP as CBMT': '2009', 'Approved by MINESUP as HIBMAT-BUEA (orders 11/0041/MINESUP and 10/04333/L/DDES/ESUP/SER, 03 August 2010)': '2010', 'Steady enrolment growth at minimum 80% annually': ' 2010-2012', 'Acquired land and started second campus construction': '2011', 'Signed MOU with University of Bamenda for top-up degrees': '2013', 'Graduated about 11th batch from bachelor program (original estimate; now extended)': 'Up to ~2024', 'Restructured to university institute, renamed HUIB (authorization 22-02654/L/MINESUP/DDES/SD-ESUP/SDA/LAN, 20 April 2022)': 'April 2022', 'Extension of SPA with University of Bamenda for B-Tech and MBA': 'December 30, 2020', 'Framework and Specific Agreements with University of Buea for B.Sc programs': 'June 17, 2021', 'May 23, 2025: Extended strategic agreement with UB for health education': 'May 23, 2025:', 'Hosted South West HND Practicals in engineering.': 'April 28, 2025', 'Students began 2025/2026 academic year.': 'October 29, 2025', 'President inspected painting works at Campus C.': 'November 4, 2025', 'New student welcome event.': 'November 22, 2025', ' MBA thesis defenses': ' November 27, 2025', '15th Matriculation Ceremony in Buea.': 'November 29, 2025', '7th Matriculation Ceremony in Douala.': 'December 11, 2025'}


def Huib_bot():
    
    print("--- HUIB AI Assistant ---")
    quer=input("you: ").strip().capitalize()
    query=quer.split()
    i=0
    while i < len(query):
        if query[i]==('challenges' or 'Challenges' or 'challenge' or 'Challenge'):
            print(f'HUIB AI: {HUIBAI.get(query)}')
            break
        elif query[i]==('Programs' or 'Program' or 'programs' 'program' or 'Qualifications' or 'Qualification' or 'qualifications' or 'qualification' ) :
            print(f'HUIB AI: {HUIBAI.get(query)}')
            break
        elif query[i]==('Campuses' or 'Infrastructure'):
            print(f'HUIB AI: {HUIBAI.get(query)}')
            break
        elif query[i]==('Administration' 'administration' or 'Overview' or 'overview'):
            print(f'HUIB AI: {HUIBAI.get(query)}')
            break
        elif query[i] == 'Role' or query[i] == 'Who': # Fixed the 'or' logic check
            n = 0
            while n < len(query):
                m = 0
                role_keys = list(Role.keys()) 
                while m < len(role_keys):     
                    key = role_keys[m]
                    if query[n].lower() in key.lower(): 
                        print(f'HUIB AI: {key} - {Role[key]}')
                        break
                    m += 1
                n += 1
        elif query[i] == 'When':
            n = 0
            while n < len(query):
                m = 0
                when_keys = list(When.keys()) 
                while m < len(when_keys):     
                    key = when_keys[m]
                    if query[n] in key:      
                        print(f'HUIB AI: {key}: {When[key]}')
                        break
                    m += 1
                n += 1

        else:
            print("Sorry can't help you with that ")
            break
        i+=1    

x=0
while x>=0:
    Huib_bot()
# Out:
# --- HUIB AI Assistant ---
# you: when was it created
# HUIB AI: Formally accredited by MINEFOP as CBMT: 2009
# Sorry can't help you with that
# --- HUIB AI Assistant ---
# you: who is the owner
# HUIB AI: Director of Administration (Head of Admin, Oversees Supervisors) - Dr. Patrick Akamin
# HUIB AI: Owner - Dr. Jude Chilaka (supervisory governance role over the entire institution).
# Sorry can't help you with that
# --- HUIB AI Assistant ---
# you: who is the dean
# HUIB AI: Director of Administration (Head of Admin, Oversees Supervisors) - Dr. Patrick Akamin
# HUIB AI: Dean of Studies - Coordinates student and lecturer affairs (answerable to Rector, heads Deputy Dean)
# Sorry can't help you with that
# --- HUIB AI Assistant ---
# you: what role does the rector play
# Sorry can't help you with that
# --- HUIB AI Assistant ---
# you: who is the finance officer
# HUIB AI: Director of Administration (Head of Admin, Oversees Supervisors) - Dr. Patrick Akamin
# ...
