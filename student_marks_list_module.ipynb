# %%
import student_marks_list_module


studentMarks=[]
numOfStudents=int(input("enter the number of student/s in your class "))

x=0
y=1
for x in range(0,numOfStudents):
    studentMark=(int(input(f"enter the score of the {y}st student ")))
    if studentMark<=20:
        studentMarks.append(studentMark)
    else:
        print()
        print("Student marks must not be greater than 20")
        break
    
    y+=1
print()
if len(studentMarks)>0:
    student_marks_list_module.studentMarksList(studentMarks,numOfStudents)
# Out:
# enter the number of student/s in your class 2
# enter the score of the 1st student 20
# enter the score of the 2st student 6
#
# class of 2
# Class average= 13.0
# Class highest score= 20
# the sorted list in ascending order is [6, 20]
